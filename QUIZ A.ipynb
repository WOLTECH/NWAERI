# %%
#Question 2
import pandas as pd
import numpy as np
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#Question 3
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data
print(fuel_data)
fuel_data_lowest=fuel_data['fuel_cost_per_unit_burned'].groupby(fuel_data['fuel_type_code_pudl'])
fuel_data_lowest.mean()
print(fuel_data_lowest.mean())
fuel_data_lowest.mean().min()
print(fuel_data_lowest.mean().min())
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64
# 13.659396569737135

# %%
#Question 4
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data[['fuel_mmbtu_per_unit']].describe()
print(fuel_data[['fuel_mmbtu_per_unit']].describe())
# Out:
#        fuel_mmbtu_per_unit
# count         29523.000000
# mean              8.492111
# std              10.600220
# min               0.000001
# 25%               1.024000
# 50%               5.762694
# 75%              17.006000
# max             341.260000

# %%
#Question 5
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data[['fuel_qty_burned']].kurt()
print(fuel_data[['fuel_qty_burned']].kurt())
fuel_data[['fuel_qty_burned']].skew()
print(fuel_data[['fuel_qty_burned']].skew())
# Out:
# fuel_qty_burned    651.36945
# dtype: float64
# fuel_qty_burned    15.851495
# dtype: float64

# %%
#Question 6
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data.isnull().sum()
print(fuel_data.isnull().sum())
fuel_data.notnull().sum()
print(fuel_data.notnull().sum())
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
# record_id                       29523
# utility_id_ferc1                29523
# report_year                     29523
# plant_name_ferc1                29523
# fuel_type_code_pudl             29523
# fuel_unit                       29343
# fuel_qty_burned                 29523
# fuel_mmbtu_per_unit             29523
# fuel_cost_per_unit_burned       29523
# fuel_cost_per_unit_delivered    29523
# fuel_cost_per_mmbtu             29523
# dtype: int64

# %%
#Question 8
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data.corr()
print(fuel_data.corr())
fuel_data.corr().unstack().sort_values(ascending=False)
print(fuel_data.corr().unstack().sort_values(ascending=False))
# Out:
#                               utility_id_ferc1  ...  fuel_cost_per_mmbtu
# utility_id_ferc1                      1.000000  ...             0.006122
# report_year                           0.093323  ...             0.010261
# fuel_qty_burned                      -0.057447  ...            -0.001896
# fuel_mmbtu_per_unit                  -0.066946  ...            -0.005884
# fuel_cost_per_unit_burned            -0.037863  ...            -0.000437
# fuel_cost_per_unit_delivered         -0.016414  ...            -0.000109
# fuel_cost_per_mmbtu                   0.006122  ...             1.000000
#
# [7 rows x 7 columns]
# fuel_cost_per_mmbtu           fuel_cost_per_mmbtu             1.000000
# fuel_cost_per_unit_delivered  fuel_cost_per_unit_delivered    1.000000
# report_year                   report_year                     1.000000
# fuel_qty_burned               fuel_qty_burned                 1.000000
# fuel_cost_per_unit_burned     fuel_cost_per_unit_burned       1.000000
# ...

# %%
#Question 9
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data.pivot_table('fuel_cost_per_unit_burned', index='report_year', columns='fuel_type_code_pudl', aggfunc='sum')
print(fuel_data.pivot_table('fuel_cost_per_unit_burned', index='report_year', columns='fuel_type_code_pudl', aggfunc='sum'))
# Out:
# fuel_type_code_pudl        coal        gas  ...    other    waste
# report_year                                 ...
# 1994                  14984.572  10792.496  ...  116.737   52.762
# 1995                  14571.785   9087.905  ...  183.577 -192.699
# 1996                  12694.803   1467.390  ...  160.075   88.092
# 1997                  43742.178   1518.471  ...  153.923  137.433
# 1998                  11902.597   7475.596  ...  225.428  238.109
# 1999                  16303.468  16767.895  ...  271.579  143.025
# 2000                 100428.831  10024.878  ...  100.014 -489.141
# 2001                  15109.012  10360.348  ...   71.283  217.499
# 2002                   9171.164   3584.279  ...   -4.257  254.438
# 2003                  30954.110   7170.143  ...  -51.286  161.973
# 2004                   9632.063   5019.023  ...  174.796  272.512
# 2005                  11107.182   3833.652  ...   76.196  313.457
# ...

# %%
#Question 10
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
fuel_data=pd.read_csv(url, error_bad_lines=False)
fuel_data_highest=fuel_data['fuel_cost_per_unit_delivered'].groupby(fuel_data['report_year'])
fuel_data_highest.mean()
print(fuel_data_highest.mean())
fuel_data_highest.mean().max()
print(fuel_data_highest.mean().max())
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64
# 11140.19723948813
